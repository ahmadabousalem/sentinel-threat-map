# %% [markdown]
# <a href="https://colab.research.google.com/github/ahmadabousalem/sentinel-threat-map/blob/main/risk%20colour%20map2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install feedparser pandas --quiet

import feedparser
import pandas as pd

# Define cities you want to monitor
cities = ["Beirut", "Baghdad", "Damascus", "Gaza"]

# RSS news feeds
rss_feeds = [
    "http://feeds.bbci.co.uk/news/world/middle_east/rss.xml",
    "https://www.aljazeera.com/xml/rss/all.xml",
    "https://rss.dw.com/rdf/rss-en-all"
]

# Fetch and filter articles
def fetch_articles():
    articles = []
    for feed_url in rss_feeds:
        feed = feedparser.parse(feed_url)
        for entry in feed.entries:
            for city in cities:
                if city.lower() in entry.title.lower() or city.lower() in entry.summary.lower():
                    articles.append({
                        "City": city,
                        "Title": entry.title,
                        "Summary": entry.summary[:200],
                        "Published": entry.published if "published" in entry else "N/A",
                        "Link": entry.link
                    })
    return pd.DataFrame(articles)

# Fetch and display
df = fetch_articles()
df.head(10)  # Show first 10 articles
# Out:
#    City                                              Title  \
# 0  Gaza  The secret system Hamas uses to pay government...
# 1  Gaza  Twenty killed after trucks overturn in Gaza, H...
# 2  Gaza  Netanyahu to propose full reoccupation of Gaza...
# 3  Gaza  He is a human skeleton, Gaza hostage's brother...
# 4  Gaza  Hundreds of Israeli ex-officials appeal to Tru...
# 5  Gaza  World leaders condemn videos of emaciated Isra...
# 6  Gaza  Aid group says worker killed by Israeli milita...
# 7  Gaza  Trump envoy visits controversial Gaza aid dist...
# 8  Gaza  France suspends Gaza evacuations after student...
# 9  Gaza  Gazan boy first to be treated in UK for war in...
#
#                                              Summary  \
# 0  Observers are baffled at how Hamas can pay off...
# 1  Four commercial trucks were looted in central ...
# 2  The plan will involve a complete takeover of G...
# 3  Ilay David says the Hamas video showing his br...
# 4  It comes amid reports that PM Netanyahu is pus...
# 5  Hamas said it would allow Red Cross access if ...
# 6  The Palestine Red Crescent Society accuses Isr...
# 7  The visit with the IDF follows near daily repo...
# 8  The Palestinian student, who arrived in France...
# 9  Majd, 15, was almost killed by an Israeli tank...
#
#                        Published  \
# 0  Wed, 06 Aug 2025 16:48:57 GMT
# 1  Wed, 06 Aug 2025 20:06:46 GMT
# 2  Tue, 05 Aug 2025 15:06:52 GMT
# 3  Mon, 04 Aug 2025 17:05:21 GMT
# 4  Mon, 04 Aug 2025 13:01:22 GMT
# 5  Sun, 03 Aug 2025 21:15:58 GMT
# 6  Sun, 03 Aug 2025 21:43:27 GMT
# 7  Fri, 01 Aug 2025 18:14:15 GMT
# 8  Fri, 01 Aug 2025 17:15:39 GMT
# 9  Thu, 31 Jul 2025 18:07:39 GMT
#
#                                                 Link
# 0  https://www.bbc.com/news/articles/c1kz42j92jmo...
# 1  https://www.bbc.com/news/articles/cz60dy2908do...
# 2  https://www.bbc.com/news/articles/cpqv2qjg5vvo...
# 3  https://www.bbc.com/news/articles/cewyk4ezeedo...
# 4  https://www.bbc.com/news/articles/crkznje8nz8o...
# 5  https://www.bbc.com/news/articles/crr2dwn7q40o...
# 6  https://www.bbc.com/news/articles/cx2x5eyl676o...
# 7  https://www.bbc.com/news/articles/c8x5jnl5eygo...
# 8  https://www.bbc.com/news/articles/c5yl7n42325o...
# 9  https://www.bbc.com/news/articles/cvgn6979n59o...

# %%
import folium
from folium.plugins import MarkerCluster
import pandas as pd

# Define key Middle East cities and placeholder risk scores
data = [
    {"city": "Beirut", "lat": 33.8938, "lon": 35.5018, "risk": 70},
    {"city": "Baghdad", "lat": 33.3152, "lon": 44.3661, "risk": 85},
    {"city": "Gaza", "lat": 31.5, "lon": 34.4667, "risk": 95},
    {"city": "Damascus", "lat": 33.5138, "lon": 36.2765, "risk": 75}
]

df = pd.DataFrame(data)

# %%
# Create base map centered over the Middle East
m = folium.Map(location=[33.5, 40], zoom_start=6, tiles="CartoDB positron")

# Create a marker cluster to group cities
marker_cluster = MarkerCluster().add_to(m)

# Function to assign color based on risk level
def risk_color(risk):
    if risk >= 90:
        return 'darkred'
    elif risk >= 75:
        return 'red'
    elif risk >= 60:
        return 'orange'
    else:
        return 'green'

# Add cities with color-coded risk markers
for _, row in df.iterrows():
    folium.CircleMarker(
        location=[row["lat"], row["lon"]],
        radius=10,
        popup=folium.Popup(f"{row['city']} - Risk Score: {row['risk']}", max_width=250),
        color=risk_color(row["risk"]),
        fill=True,
        fill_color=risk_color(row["risk"]),
        fill_opacity=0.7
    ).add_to(marker_cluster)

# Display the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2c4820e40959eec3e50655759fffb982 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2c4820e40959eec3e50655759fffb982&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2c4820e40959eec3e50655759fffb982 = L.map(
#                 &quot;map_2c4820e40959eec3e50655759fffb982&quot;,
#                 {
#                     center: [33.5, 40.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_987706b0dec9b788c73554eff9dedc1c = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_987706b0dec9b788c73554eff9dedc1c.addTo(map_2c4820e40959eec3e50655759fffb982);
#
#
#             var marker_cluster_7fe10f9b4693a3cf90e1481fdfbaedbd = L.markerClusterGroup(
#                 {
# }
#             );
#
#
#             var circle_marker_241ffb598fe63cbc030285d05a065f7f = L.circleMarker(
#                 [33.8938, 35.5018],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;orange&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;orange&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(marker_cluster_7fe10f9b4693a3cf90e1481fdfbaedbd);
#
#
#         var popup_0184348f394fe93ee8010e45a46dff9d = L.popup({
#   &quot;maxWidth&quot;: 250,
# });
#
#
#
#                 var html_9ea8fbb771cfba77d11a5bece165b541 = $(`&lt;div id=&quot;html_9ea8fbb771cfba77d11a5bece165b541&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Beirut - Risk Score: 70&lt;/div&gt;`)[0];
#                 popup_0184348f394fe93ee8010e45a46dff9d.setContent(html_9ea8fbb771cfba77d11a5bece165b541);
#
#
#
#         circle_marker_241ffb598fe63cbc030285d05a065f7f.bindPopup(popup_0184348f394fe93ee8010e45a46dff9d)
#         ;
#
#
#
#
#             var circle_marker_88a3992f03a1bd7c63a22be8704b8838 = L.circleMarker(
#                 [33.3152, 44.3661],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(marker_cluster_7fe10f9b4693a3cf90e1481fdfbaedbd);
#
#
#         var popup_a660e18d38542887ce08b0847af74bf8 = L.popup({
#   &quot;maxWidth&quot;: 250,
# });
#
#
#
#                 var html_aa0e461fb6597c3fea71cf553e3efe33 = $(`&lt;div id=&quot;html_aa0e461fb6597c3fea71cf553e3efe33&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Baghdad - Risk Score: 85&lt;/div&gt;`)[0];
#                 popup_a660e18d38542887ce08b0847af74bf8.setContent(html_aa0e461fb6597c3fea71cf553e3efe33);
#
#
#
#         circle_marker_88a3992f03a1bd7c63a22be8704b8838.bindPopup(popup_a660e18d38542887ce08b0847af74bf8)
#         ;
#
#
#
#
#             var circle_marker_988ce44784a25a3dc4e299cd00978197 = L.circleMarker(
#                 [31.5, 34.4667],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;darkred&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;darkred&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(marker_cluster_7fe10f9b4693a3cf90e1481f

# %%
pip install feedparser pandas folium --quiet

# %%
# !pip install feedparser pandas folium
# Out:
# Requirement already satisfied: feedparser in /usr/local/lib/python3.11/dist-packages (6.0.11)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (2.2.2)
# Requirement already satisfied: folium in /usr/local/lib/python3.11/dist-packages (0.20.0)
# Requirement already satisfied: sgmllib3k in /usr/local/lib/python3.11/dist-packages (from feedparser) (1.0.0)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: branca>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from folium) (0.8.1)
# Requirement already satisfied: jinja2>=2.9 in /usr/local/lib/python3.11/dist-packages (from folium) (3.1.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from folium) (2.32.3)
# Requirement already satisfied: xyzservices in /usr/local/lib/python3.11/dist-packages (from folium) (2025.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2>=2.9->folium) (3.0.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->folium) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->folium) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->folium) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->folium) (2025.7.14)

# %%
# !pip install feedparser folium pandas --quiet

import feedparser
import folium
import pandas as pd
from datetime import datetime

# %%
# Define the cities to monitor
cities = {
    "Beirut": {"lat": 33.8938, "lon": 35.5018},
    "Baghdad": {"lat": 33.3152, "lon": 44.3661},
    "Damascus": {"lat": 33.5138, "lon": 36.2765},
    "Gaza": {"lat": 31.5, "lon": 34.47}
}

# Add your open-source RSS feeds
rss_feeds = {
    "Al Jazeera": "https://www.aljazeera.com/xml/rss/all.xml",
    "BBC": "http://feeds.bbci.co.uk/news/world/rss.xml",
    "DW": "https://rss.dw.com/rdf/rss-en-all",
    "CNN": "http://rss.cnn.com/rss/edition_world.rss",
    "Reuters": "http://feeds.reuters.com/Reuters/worldNews"
}

# Keywords to look for
risk_keywords = ['attack', 'explosion', 'war', 'strike', 'missile', 'death', 'protest', 'conflict', 'rocket', 'terror']

# Create an empty list to store data
data = []

# Loop through feeds
for source, url in rss_feeds.items():
    feed = feedparser.parse(url)
    for entry in feed.entries:
        entry_text = (entry.title + " " + entry.get("description", "")).lower()
        for city in cities:
            if city.lower() in entry_text:
                risk_score = sum(1 for kw in risk_keywords if kw in entry_text)
                data.append({
                    "city": city,
                    "source": source,
                    "title": entry.title,
                    "published": entry.get("published", "N/A"),
                    "score": risk_score
                })

# Convert to DataFrame
df = pd.DataFrame(data)
df = df.groupby("city").agg({"score": "sum"}).reset_index()

# %%
# Create the base map
m = folium.Map(location=[33.8938, 35.5018], zoom_start=6)

# Add risk circles
for index, row in df.iterrows():
    city = row['city']
    score = row['score']
    location = [cities[city]["lat"], cities[city]["lon"]]

    folium.CircleMarker(
        location=location,
        radius=5 + score * 2,
        color='red' if score > 3 else 'orange',
        fill=True,
        fill_color='red' if score > 3 else 'orange',
        fill_opacity=0.7,
        popup=f"{city} - Risk Score: {score}"
    ).add_to(m)

# Save and show map
m.save("sentinel_risk_map.html")
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_11d87bef50f80bbeb98ff1c6eb33efe8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_11d87bef50f80bbeb98ff1c6eb33efe8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_11d87bef50f80bbeb98ff1c6eb33efe8 = L.map(
#                 &quot;map_11d87bef50f80bbeb98ff1c6eb33efe8&quot;,
#                 {
#                     center: [33.8938, 35.5018],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_fb7f615dca1bcffee9e00727ed9a5111 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_fb7f615dca1bcffee9e00727ed9a5111.addTo(map_11d87bef50f80bbeb98ff1c6eb33efe8);
#
#
#             var circle_marker_4e694776d4b0ca21f07cf8227adfcd8a = L.circleMarker(
#                 [33.5138, 36.2765],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;orange&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;orange&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 7, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_11d87bef50f80bbeb98ff1c6eb33efe8);
#
#
#         var popup_27951f387c55ce58f02903b3da84e70c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ee71ad5c8d89204652fd98ce8c276e99 = $(`&lt;div id=&quot;html_ee71ad5c8d89204652fd98ce8c276e99&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Damascus - Risk Score: 1&lt;/div&gt;`)[0];
#                 popup_27951f387c55ce58f02903b3da84e70c.setContent(html_ee71ad5c8d89204652fd98ce8c276e99);
#
#
#
#         circle_marker_4e694776d4b0ca21f07cf8227adfcd8a.bindPopup(popup_27951f387c55ce58f02903b3da84e70c)
#         ;
#
#
#
#
#             var circle_marker_fb83f6782c5314e1640a3062d1793373 = L.circleMarker(
#                 [31.5, 34.47],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 15, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_11d87bef50f80bbeb98ff1c6eb33efe8);
#
#
#         var popup_5310c5f0dd76d9e74c7c9abcec33e4c1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f01e60cf730b1a6709b3844e629ff034 = $(`&lt;div id=&quot;html_f01e60cf730b1a6709b3844e629ff034&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Gaza - Risk Score: 5&lt;/div&gt;`)[0];
#                 popup_5310c5f0dd76d9e74c7c9abcec33e4c1.setContent(html_f01e60cf730b1a6709b3844e629ff034);
#
#
#
#         circle_marker_fb83f6782c5314e1640a3062d1793373.bindPopup(popup_5310c5f0dd76d9e74c7c9abcec33e4c1)
#         ;
#
#
#
#
#             tile_layer_fb7f615dca1bcffee9e00727ed9a5111.addTo(map_11d87bef50f80bbeb98ff1c6eb33efe8);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
import feedparser
import pandas as pd
import folium

# %%
city_coords = {
    "Beirut": (33.8938, 35.5018),
    "Baghdad": (33.3152, 44.3661),
    "Damascus": (33.5138, 36.2765),
    "Jerusalem": (31.7683, 35.2137)
}

# %%
rss_feeds = [
    "http://feeds.bbci.co.uk/news/world/middle_east/rss.xml"
]

# %%
def fetch_risk_data(cities, feeds):
    counts = {city: 0 for city in cities}
    for feed_url in feeds:
        feed = feedparser.parse(feed_url)
        for entry in feed.entries:
            title = entry.title.lower()
            for city in cities:
                if city.lower() in title:
                    counts[city] += 1
    return counts

# %%
def get_risk_level(count):
    if count > 5:
        return "High"
    elif count > 2:
        return "Medium"
    elif count >= 0:
        return "Low"
    else:
        return "No data"

# %%
import feedparser
import pandas as pd
import folium
from datetime import datetime

# Define cities and their coordinates
cities = {
    "Gaza": (31.5, 34.47),
    "Beirut": (33.89, 35.50),
    "Baghdad": (33.31, 44.36),
    "Damascus": (33.51, 36.29)
}

# RSS feeds from major open sources
rss_feeds = [
    "http://feeds.bbci.co.uk/news/world/middle_east/rss.xml",
    "https://www.aljazeera.com/xml/rss/all.xml",
    "https://www.dw.com/en/top-stories/world/s-1429?maca=en-rss-en-all-1573-rdf",
    "https://www.reuters.com/rssFeed/topNews"
]

# Fetch and filter news
def fetch_city_news(city):
    city_news = []
    for feed_url in rss_feeds:
        feed = feedparser.parse(feed_url)
        for entry in feed.entries:
            if city.lower() in entry.title.lower() or city.lower() in entry.get("summary", "").lower():
                city_news.append({
                    "city": city,
                    "title": entry.title,
                    "summary": entry.get("summary", ""),
                    "link": entry.link,
                    "published": entry.get("published", "Unknown")
                })
    return city_news

# Collect news for all cities
all_news = []
for city in cities:
    city_articles = fetch_city_news(city)
    all_news.extend(city_articles)

# Convert to DataFrame
df = pd.DataFrame(all_news)

# Assign basic risk score: more news = higher risk
risk_data = df['city'].value_counts().to_dict()

# Display news table (optional)
print("📰 Latest News from Target Cities:\n")
display(df[['city', 'title', 'published', 'link']])

# Create map with risk circles
risk_map = folium.Map(location=[33.5, 40], zoom_start=5)

for city, (lat, lon) in cities.items():
    count = risk_data.get(city, 0)
    risk_score = min(count * 5, 100)  # Max risk score 100
    folium.CircleMarker(
        location=(lat, lon),
        radius=10,
        color='red' if risk_score > 50 else 'orange' if risk_score > 20 else 'green',
        fill=True,
        fill_opacity=0.7,
        popup=f"{city} — Risk Score: {risk_score} ({count} articles)"
    ).add_to(risk_map)

# Show map
risk_map
# Out:
# 📰 Latest News from Target Cities:
#         city                                              title  \
# 0       Gaza  The secret system Hamas uses to pay government...
# 1       Gaza  Twenty killed after trucks overturn in Gaza, H...
# 2       Gaza  Netanyahu to propose full reoccupation of Gaza...
# 3       Gaza  He is a human skeleton, Gaza hostage's brother...
# 4       Gaza  Hundreds of Israeli ex-officials appeal to Tru...
# 5       Gaza  World leaders condemn videos of emaciated Isra...
# 6       Gaza  Aid group says worker killed by Israeli milita...
# 7       Gaza  Trump envoy visits controversial Gaza aid dist...
# 8       Gaza  France suspends Gaza evacuations after student...
# 9       Gaza  Gazan boy first to be treated in UK for war in...
# 10      Gaza  US allies break with Trump to force diplomatic...
# 11      Gaza  Gaza aid site offered a 'women only' day. It d...
# 12      Gaza  He went to get aid and didn't come back - stor...
# 13      Gaza  We might get killed, but we have to get food, ...
# 14      Gaza  Church leaders return with 'broken hearts' aft...
# 15      Gaza    The Today Debate: What can stop the war in Gaza
# 16      Gaza  Jeremy Bowen: Israel's allies see evidence of ...
# 17      Gaza  Two girls shot in Gaza - BBC pieces together w...
# 18      Gaza    Gazan mother of malnourished baby speaks to BBC
# 19      Gaza  Watch: How did Gaza get to the brink of starva...
# 20      Gaza  BBC presses UK foreign secretary on timing of ...
# 21      Gaza    Gazan mother of malnourished baby speaks to BBC
# 22      Gaza  Watch: BBC's Jeremy Bowen goes onboard a plane...
# 23      Gaza  'I'm so tired': Mother of starving Gazan baby ...
# 24      Gaza  'I witnessed war crimes' in Gaza, former worke...
# 25      Gaza  Watch: Protesters pack Tel Aviv square to dema...
# 26      Gaza  'All the people are hungry': Voices from Gaza ...
# 27      Gaza  Call for end to forced starvation, targeted ki...
# 28      Gaza  Israeli captive families confront police outsi...
# 29      Gaza  Dire blood shortage in Gaza as deaths from Isr...
# 30      Gaza       Israeli settlers block Gaza-bound aid trucks
# 31  Damascus  Syria signs $14bn infrastructure deals, will r...
#
#                           published  \
# 0     Wed, 06 Aug 2025 16:48:57 GMT
# 1     Wed, 06 Aug 2025 20:06:46 GMT
# 2     Tue, 05 Aug 2025 15:06:52 GMT
# 3     Mon, 04 Aug 2025 17:05:21 GMT
# 4     Mon, 04 Aug 2025 13:01:22 GMT
# 5     Sun, 03 Aug 2025 21:15:58 GMT
# 6     Sun, 03 Aug 2025 21:43:27 GMT
# 7     Fri, 01 Aug 2025 18:14:15 GMT
# 8     Fri, 01 Aug 2025 17:15:39 GMT
# 9     Thu, 31 Jul 2025 18:07:39 GMT
# 10    Thu, 31 Jul 2025 01:44:50 GMT
# 11    Sat, 26 Jul 2025 18:05:36 GMT
# 12    Fri, 25 Jul 2025 16:12:22 GMT
# 13    Thu, 24 Jul 2025 13:36:49 GMT
# 14    Wed, 23 Jul 2025 10:21:55 GMT
# 15    Tue, 22 Jul 2025 21:08:22 GMT
# 16    Tue, 22 Jul 2025 16:54:01 GMT
# 17    Fri, 01 Aug 2025 05:07:20 GMT
# 18    Tue, 29 Jul 2025 18:18:00 GMT
# 19    Tue, 29 Jul 2025 19:46:33 GMT
# 20    Tue, 29 Jul 2025 21:51:43 GMT
# 21    Tue, 29 Jul 2025 18:18:00 GMT
# 22    Mon, 28 Jul 2025 18:36:31 GMT
# 23    Fri, 25 Jul 2025 18:21:29 GMT
# 24    Fri, 25 Jul 2025 22:10:39 GMT
# 25    Fri, 25 Jul 2025 13:16:50 GMT
# 26    Fri, 25 Jul 2025 14:03:55 GMT
# 27  Wed, 06 Aug 2025 22:27:49 +0000
# 28  Wed, 06 Aug 2025 20:43:27 +0000
# 29  Wed, 06 Aug 2025 20:32:35 +0000
# 30  Wed, 06 Aug 2025 15:56:43 +0000
# 31  Wed, 06 Aug 2025 17:44:03 +0000
#
#                                                  link
# 0   https://www.bbc.com/news/articles/c1kz42j92jmo...
# 1   https://www.bbc.com/news/articles/cz60dy2908do...
# 2   https://www.bbc.com/news/articles/cpqv2qjg5vvo...
# 3   https://www.bbc.com/news/articles/cewyk4ezeedo...
# 4   https://www.bbc.com/news/articles/crkznje8nz8o...
# 5   https://www.bbc.com/news/articles/crr2dwn7q40o...
# 6   https://www.bbc.com/news/articles/cx2x5eyl676o...
# 7   https://www.bbc.com/news/articles/c8x5jnl5eygo...
# 8   https://www.bbc.com/news/articles/c5yl7n42325o...
# 9   https://www.bbc.com/news/articles/cvgn6979n59o...
# 10  https://www.bbc.com/news/articles/cly6rl6158no...
# 11  https://www.bbc.com/news/articles/c74z4gy5g31o...
# 12  https://www.bbc.com/news/articles/cvgn2rwk2lyo...
# 13  https://www.bbc.com/news/articles/c4g2gw62jnpo...
# 14  https://www.bbc.com/news/articles/cm2ljemmnyko...
# 15  https://www.bbc.com/news/videos/cj0m5285d43o?a...
# 16  https://www.bbc.com/news/articles/cp863mln0pmo...
# 17  https://www.bbc.com/news/videos/cjelp738zd7o?a...
# 18  https://www.bbc.com/news/videos/cgerj7qnprno?a...
# 19  https://www.bbc.com/news/videos/cjey0v4xjz9o?a...
# 20  https://www.bbc.com/news/videos/c9d0lj9q9j6o?a...
# 21  https://www.bbc.com/news/videos/cgerj7qnprno?a...
# 22  https://www.bbc.com/news/videos/clyj4gnzxgno?a...
# 23  https://www.bbc.com/news/videos/c4gdg13rrx4o?a...
# 24  https://www.bbc.com/news/videos/cy8k8045nx9o?a...
# 25  https://www.bbc.com/news/videos/cgq7qpqz27qo?a...
# 26  https://www.bbc.com/news/videos/c4g8gy52dwgo?a...
# 27  https://www.aljazeera.com/news/2025/8/6/call-f...
# 28  https://www.aljazeera.com/news/2025/8/6/israel...
# 29  https://www.aljazeera.com/news/2025/8/6/dire-b...
# 30  https://www.aljazeera.com/video/newsfeed/2025/...
# 31  https://www.aljazeera.com/news/2025/8/6/syria-...
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e8afad99896f71d9461559fa33dacf50 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e8afad99896f71d9461559fa33dacf50&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e8afad99896f71d9461559fa33dacf50 = L.map(
#                 &quot;map_e8afad99896f71d9461559fa33dacf50&quot;,
#                 {
#                     center: [33.5, 40.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_fe8974a1b7ef3ed46c51bcfb0d6da7fd = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_fe8974a1b7ef3ed46c51bcfb0d6da7fd.addTo(map_e8afad99896f71d9461559fa33dacf50);
#
#
#             var circle_marker_33202588dc86162492f95897e028e3ba = L.circleMarker(
#                 [31.5, 34.47],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_e8afad99896f71d9461559fa33dacf50);
#
#
#         var popup_775821c4941c352e5be074a08ea4d145 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_49108951cffbf60d1edb6f31fc48fa3d = $(`&lt;div id=&quot;html_49108951cffbf60d1edb6f31fc48fa3d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Gaza — Risk Score: 100 (31 articles)&lt;/div&gt;`)[0];
#                 popup_775821c4941c352e5be074a08ea4d145.setContent(html_49108951cffbf60d1edb6f31fc48fa3d);
#
#
#
#         circle_marker_33202588dc86162492f95897e028e3ba.bindPopup(popup_775821c4941c352e5be074a08ea4d145)
#         ;
#
#
#
#
#             var circle_marker_9779e457c2f9720457d1346adcc417bf = L.circleMarker(
#                 [33.89, 35.5],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_e8afad99896f71d9461559fa33dacf50);
#
#
#         var popup_2918c20d683d8797c03fd30b1bd7cb5d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a0266fd9223a170ad3ea4ff208443027 = $(`&lt;div id=&quot;html_a0266fd9223a170ad3ea4ff208443027&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Beirut — Risk Score: 0 (0 articles)&lt;/div&gt;`)[0];
#                 popup_2918c20d683d8797c03fd30b1bd7cb5d.setContent(html_a0266fd9223a170ad3ea4ff208443027);
#
#
#
#         circle_marker_9779e457c2f9720457d1346adcc417bf.bindPopup(popup_2918c20d683d8797c03fd30b1bd7cb5d)
#         ;
#
#
#
#
#             var circle_marker_5eb61eba1d2ec75d388b80ed13ce67e1 = L.circleMarker(
#                 [33.31, 44.36],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_e8afad99896f71d9461559fa33dacf50);
#
#
#         var popup_ae8bb8de2a6c36b659ca37c398df1923 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7f1eeb884dd6afe02751119a78e6bf87 = $(`&lt;div id=&quot;html_7f1eeb884dd6afe02751119a78e6bf87&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Baghdad — Risk Score: 0 (0 articles)&lt;/div&gt;`)[0];
#                 popup_ae8bb8de2a6c36b659ca37c398df1923.setContent(html_7f1eeb884dd6afe02751119a78e6bf87);
#
#
#
#         circle_marker_5eb61eba1d2ec75d388b80ed13ce67e1.bindPopup(popup_ae8bb8de2a6c36b659ca37c398df1923)
#         ;
#
#
#
#
#             var circle_marker_10659800386

# %%
risk_data = fetch_risk_data(city_coords.keys(), rss_feeds)
print("Risk data:", risk_data)
# Out:
# Risk data: {'Beirut': 0, 'Baghdad': 0, 'Damascus': 1, 'Jerusalem': 1}

# %%
m = folium.Map(location=[33.5, 36.5], zoom_start=6)

for city, coords in city_coords.items():
    count = risk_data.get(city, 0)
    risk = get_risk_level(count)
    color = {"High": "red", "Medium": "orange", "Low": "green", "No data": "gray"}.get(risk, "gray")
    folium.Marker(
        location=coords,
        popup=f"<b>{city}</b><br>Articles: {count}<br>Risk: {risk}",
        tooltip=f"{city}: {risk}",
        icon=folium.Icon(color=color)
    ).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f9ea7731e78c01fd0753cf5b460a7169 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f9ea7731e78c01fd0753cf5b460a7169&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f9ea7731e78c01fd0753cf5b460a7169 = L.map(
#                 &quot;map_f9ea7731e78c01fd0753cf5b460a7169&quot;,
#                 {
#                     center: [33.5, 36.5],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_58d1eaff5a5fc65157348f1bd74b810d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_58d1eaff5a5fc65157348f1bd74b810d.addTo(map_f9ea7731e78c01fd0753cf5b460a7169);
#
#
#             var marker_d165bb3ddbd7c35a0436f038a8e5b10a = L.marker(
#                 [33.8938, 35.5018],
#                 {
# }
#             ).addTo(map_f9ea7731e78c01fd0753cf5b460a7169);
#
#
#             var icon_4af6a2ee00560fbaf051ae52ae5a87e2 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_3d62ad3ccd6315bada9d3f93bfeabed3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b511e81ea3a165d14b3200b23f0341e3 = $(`&lt;div id=&quot;html_b511e81ea3a165d14b3200b23f0341e3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Beirut&lt;/b&gt;&lt;br&gt;Articles: 0&lt;br&gt;Risk: Low&lt;/div&gt;`)[0];
#                 popup_3d62ad3ccd6315bada9d3f93bfeabed3.setContent(html_b511e81ea3a165d14b3200b23f0341e3);
#
#
#
#         marker_d165bb3ddbd7c35a0436f038a8e5b10a.bindPopup(popup_3d62ad3ccd6315bada9d3f93bfeabed3)
#         ;
#
#
#
#
#             marker_d165bb3ddbd7c35a0436f038a8e5b10a.bindTooltip(
#                 `&lt;div&gt;
#                      Beirut: Low
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_d165bb3ddbd7c35a0436f038a8e5b10a.setIcon(icon_4af6a2ee00560fbaf051ae52ae5a87e2);
#
#
#             var marker_8e8b444aee7d9dc042aaf39c5b9e5e5e = L.marker(
#                 [33.3152, 44.3661],
#                 {
# }
#             ).addTo(map_f9ea7731e78c01fd0753cf5b460a7169);
#
#
#             var icon_37e5bda1b7be3a682fd72e0e1332ace2 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_ef7dcba941bbcd414597f62e566379bd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9f173a979483ac3008cf7be79688b84a = $(`&lt;div id=&quot;html_9f173a979483ac3008cf7be79688b84a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Baghdad&lt;/b&gt;&lt;br&gt;Articles: 0&lt;br&gt;Risk: Low&lt;/div&gt;`)[0];
#                 popup_ef7dcba941bbcd414597f62e566379bd.setContent(html_9f173a979483ac3008cf7be79688b84a);
#
#
#
#         marker_8e8b444aee7d9dc042aaf39c5b9e5e5e.bindPopup(popup_ef7dcba941bbcd414597f62e566379bd)
#         ;
#
#
#
#
#             marker_8e8b444aee7d9dc042aaf39c5b9e5e5e.bindTooltip(
#                 `&lt;div&gt;
#                      Baghdad: Low
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_8e8b444aee7d9dc042aaf39c5b9e5e5e.setIcon(icon_37e5bda1b7be3a682fd72e0e1332ace2);
#
#
#             var marker_5e3f28409d83ea38b8dcdfd2e7b34ba9 = L.marker(
#                 [33.5138, 36.2765],
#                 {
# }
#             ).addTo(map_f9ea7731e78c01fd0753cf5b460a7169);
#
#
#             var icon_4fb06b82a517e5bdeb697f267eccf77a = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_23eb22f464c55c89bb4336fc8d905ac8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_707e35e3af034c71d1cf0b23127987d0 = $(`&lt;div id
