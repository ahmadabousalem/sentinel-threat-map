# %% [markdown]
# <a href="https://colab.research.google.com/github/ahmadabousalem/sentinel-threat-map/blob/main/risk%20colour%20map.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install feedparser pandas --quiet

import feedparser
import pandas as pd

# Define cities you want to monitor
cities = ["Beirut", "Baghdad", "Damascus", "Gaza"]

# RSS news feeds
rss_feeds = [
    "http://feeds.bbci.co.uk/news/world/middle_east/rss.xml",
    "https://www.aljazeera.com/xml/rss/all.xml",
    "https://rss.dw.com/rdf/rss-en-all"
]

# Fetch and filter articles
def fetch_articles():
    articles = []
    for feed_url in rss_feeds:
        feed = feedparser.parse(feed_url)
        for entry in feed.entries:
            for city in cities:
                if city.lower() in entry.title.lower() or city.lower() in entry.summary.lower():
                    articles.append({
                        "City": city,
                        "Title": entry.title,
                        "Summary": entry.summary[:200],
                        "Published": entry.published if "published" in entry else "N/A",
                        "Link": entry.link
                    })
    return pd.DataFrame(articles)

# Fetch and display
df = fetch_articles()
df.head(10)  # Show first 10 articles
# Out:
#    City                                              Title  \
# 0  Gaza  Netanyahu to propose full reoccupation of Gaza...
# 1  Gaza  He is a human skeleton, Gaza hostage's brother...
# 2  Gaza  Hundreds of Israeli ex-officials appeal to Tru...
# 3  Gaza  World leaders condemn videos of emaciated Isra...
# 4  Gaza  Aid group says worker killed by Israeli milita...
# 5  Gaza  Trump envoy visits controversial Gaza aid dist...
# 6  Gaza  France suspends Gaza evacuations after student...
# 7  Gaza  Gazan boy first to be treated in UK for war in...
# 8  Gaza  US allies break with Trump to force diplomatic...
# 9  Gaza  Gaza aid site offered a 'women only' day. It d...
#
#                                              Summary  \
# 0  The plan will involve a complete takeover of G...
# 1  Ilay David says the Hamas video showing his br...
# 2  It comes amid reports that PM Netanyahu is pus...
# 3  Hamas said it would allow Red Cross access if ...
# 4  The Palestine Red Crescent Society accuses Isr...
# 5  The visit with the IDF follows near daily repo...
# 6  The Palestinian student, who arrived in France...
# 7  Majd, 15, was almost killed by an Israeli tank...
# 8  As Canada joins France and the UK with plans t...
# 9  Families say mothers Mary Sheikh al-Eid and Kh...
#
#                        Published  \
# 0  Tue, 05 Aug 2025 15:06:52 GMT
# 1  Mon, 04 Aug 2025 17:05:21 GMT
# 2  Mon, 04 Aug 2025 13:01:22 GMT
# 3  Sun, 03 Aug 2025 21:15:58 GMT
# 4  Sun, 03 Aug 2025 21:43:27 GMT
# 5  Fri, 01 Aug 2025 18:14:15 GMT
# 6  Fri, 01 Aug 2025 17:15:39 GMT
# 7  Thu, 31 Jul 2025 18:07:39 GMT
# 8  Thu, 31 Jul 2025 01:44:50 GMT
# 9  Sat, 26 Jul 2025 18:05:36 GMT
#
#                                                 Link
# 0  https://www.bbc.com/news/articles/cpqv2qjg5vvo...
# 1  https://www.bbc.com/news/articles/cewyk4ezeedo...
# 2  https://www.bbc.com/news/articles/crkznje8nz8o...
# 3  https://www.bbc.com/news/articles/crr2dwn7q40o...
# 4  https://www.bbc.com/news/articles/cx2x5eyl676o...
# 5  https://www.bbc.com/news/articles/c8x5jnl5eygo...
# 6  https://www.bbc.com/news/articles/c5yl7n42325o...
# 7  https://www.bbc.com/news/articles/cvgn6979n59o...
# 8  https://www.bbc.com/news/articles/cly6rl6158no...
# 9  https://www.bbc.com/news/articles/c74z4gy5g31o...

# %%
pip install feedparser pandas folium --quiet

# %%
import feedparser
import pandas as pd
import folium

# %%
city_coords = {
    "Beirut": (33.8938, 35.5018),
    "Baghdad": (33.3152, 44.3661),
    "Damascus": (33.5138, 36.2765),
    "Jerusalem": (31.7683, 35.2137)
}

# %%
rss_feeds = [
    "http://feeds.bbci.co.uk/news/world/middle_east/rss.xml"
]

# %%
def fetch_risk_data(cities, feeds):
    counts = {city: 0 for city in cities}
    for feed_url in feeds:
        feed = feedparser.parse(feed_url)
        for entry in feed.entries:
            title = entry.title.lower()
            for city in cities:
                if city.lower() in title:
                    counts[city] += 1
    return counts

# %%
def get_risk_level(count):
    if count > 5:
        return "High"
    elif count > 2:
        return "Medium"
    elif count >= 0:
        return "Low"
    else:
        return "No data"

# %%
# !pip install feedparser pandas folium
# Out:
# Requirement already satisfied: feedparser in /usr/local/lib/python3.11/dist-packages (6.0.11)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (2.2.2)
# Requirement already satisfied: folium in /usr/local/lib/python3.11/dist-packages (0.20.0)
# Requirement already satisfied: sgmllib3k in /usr/local/lib/python3.11/dist-packages (from feedparser) (1.0.0)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: branca>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from folium) (0.8.1)
# Requirement already satisfied: jinja2>=2.9 in /usr/local/lib/python3.11/dist-packages (from folium) (3.1.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from folium) (2.32.3)
# Requirement already satisfied: xyzservices in /usr/local/lib/python3.11/dist-packages (from folium) (2025.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2>=2.9->folium) (3.0.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->folium) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->folium) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->folium) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->folium) (2025.7.14)

# %%
import feedparser
import pandas as pd
import folium
from datetime import datetime

# Define cities and their coordinates
cities = {
    "Gaza": (31.5, 34.47),
    "Beirut": (33.89, 35.50),
    "Baghdad": (33.31, 44.36),
    "Damascus": (33.51, 36.29)
}

# RSS feeds from major open sources
rss_feeds = [
    "http://feeds.bbci.co.uk/news/world/middle_east/rss.xml",
    "https://www.aljazeera.com/xml/rss/all.xml",
    "https://www.dw.com/en/top-stories/world/s-1429?maca=en-rss-en-all-1573-rdf",
    "https://www.reuters.com/rssFeed/topNews"
]

# Fetch and filter news
def fetch_city_news(city):
    city_news = []
    for feed_url in rss_feeds:
        feed = feedparser.parse(feed_url)
        for entry in feed.entries:
            if city.lower() in entry.title.lower() or city.lower() in entry.get("summary", "").lower():
                city_news.append({
                    "city": city,
                    "title": entry.title,
                    "summary": entry.get("summary", ""),
                    "link": entry.link,
                    "published": entry.get("published", "Unknown")
                })
    return city_news

# Collect news for all cities
all_news = []
for city in cities:
    city_articles = fetch_city_news(city)
    all_news.extend(city_articles)

# Convert to DataFrame
df = pd.DataFrame(all_news)

# Assign basic risk score: more news = higher risk
risk_data = df['city'].value_counts().to_dict()

# Display news table (optional)
print("📰 Latest News from Target Cities:\n")
display(df[['city', 'title', 'published', 'link']])

# Create map with risk circles
risk_map = folium.Map(location=[33.5, 40], zoom_start=5)

for city, (lat, lon) in cities.items():
    count = risk_data.get(city, 0)
    risk_score = min(count * 5, 100)  # Max risk score 100
    folium.CircleMarker(
        location=(lat, lon),
        radius=10,
        color='red' if risk_score > 50 else 'orange' if risk_score > 20 else 'green',
        fill=True,
        fill_opacity=0.7,
        popup=f"{city} — Risk Score: {risk_score} ({count} articles)"
    ).add_to(risk_map)

# Show map
risk_map
# Out:
# 📰 Latest News from Target Cities:
#     city                                              title  \
# 0   Gaza  Netanyahu to propose full reoccupation of Gaza...
# 1   Gaza  He is a human skeleton, Gaza hostage's brother...
# 2   Gaza  Hundreds of Israeli ex-officials appeal to Tru...
# 3   Gaza  World leaders condemn videos of emaciated Isra...
# 4   Gaza  Aid group says worker killed by Israeli milita...
# 5   Gaza  Trump envoy visits controversial Gaza aid dist...
# 6   Gaza  France suspends Gaza evacuations after student...
# 7   Gaza  Gazan boy first to be treated in UK for war in...
# 8   Gaza  US allies break with Trump to force diplomatic...
# 9   Gaza  Gaza aid site offered a 'women only' day. It d...
# 10  Gaza  He went to get aid and didn't come back - stor...
# 11  Gaza  We might get killed, but we have to get food, ...
# 12  Gaza  Church leaders return with 'broken hearts' aft...
# 13  Gaza    The Today Debate: What can stop the war in Gaza
# 14  Gaza  Jeremy Bowen: Israel's allies see evidence of ...
# 15  Gaza  Outrage builds over plan to force all Gazans t...
# 16  Gaza  Two girls shot in Gaza - BBC pieces together w...
# 17  Gaza    Gazan mother of malnourished baby speaks to BBC
# 18  Gaza  Watch: How did Gaza get to the brink of starva...
# 19  Gaza  BBC presses UK foreign secretary on timing of ...
# 20  Gaza    Gazan mother of malnourished baby speaks to BBC
# 21  Gaza  Watch: BBC's Jeremy Bowen goes onboard a plane...
# 22  Gaza  'I'm so tired': Mother of starving Gazan baby ...
# 23  Gaza  'I witnessed war crimes' in Gaza, former worke...
# 24  Gaza  Watch: Protesters pack Tel Aviv square to dema...
# 25  Gaza  'All the people are hungry': Voices from Gaza ...
# 26  Gaza  Trump says it is ‘up to Israel’ whether to occ...
# 27  Gaza  From Amazon to the Gaza flotilla – the journey...
# 28  Gaza  Israeli forces kill more than 80 people across...
# 29  Gaza  President of Egypt accuses Israel of ‘systemat...
# 30  Gaza  How will Gaza care for the 150,000 injured in ...
#
#                           published  \
# 0     Tue, 05 Aug 2025 15:06:52 GMT
# 1     Mon, 04 Aug 2025 17:05:21 GMT
# 2     Mon, 04 Aug 2025 13:01:22 GMT
# 3     Sun, 03 Aug 2025 21:15:58 GMT
# 4     Sun, 03 Aug 2025 21:43:27 GMT
# 5     Fri, 01 Aug 2025 18:14:15 GMT
# 6     Fri, 01 Aug 2025 17:15:39 GMT
# 7     Thu, 31 Jul 2025 18:07:39 GMT
# 8     Thu, 31 Jul 2025 01:44:50 GMT
# 9     Sat, 26 Jul 2025 18:05:36 GMT
# 10    Fri, 25 Jul 2025 16:12:22 GMT
# 11    Thu, 24 Jul 2025 13:36:49 GMT
# 12    Wed, 23 Jul 2025 10:21:55 GMT
# 13    Tue, 22 Jul 2025 21:08:22 GMT
# 14    Tue, 22 Jul 2025 16:54:01 GMT
# 15    Fri, 11 Jul 2025 11:55:51 GMT
# 16    Fri, 01 Aug 2025 05:07:20 GMT
# 17    Tue, 29 Jul 2025 18:18:00 GMT
# 18    Tue, 29 Jul 2025 19:46:33 GMT
# 19    Tue, 29 Jul 2025 21:51:43 GMT
# 20    Tue, 29 Jul 2025 18:18:00 GMT
# 21    Mon, 28 Jul 2025 18:36:31 GMT
# 22    Fri, 25 Jul 2025 18:21:29 GMT
# 23    Fri, 25 Jul 2025 22:10:39 GMT
# 24    Fri, 25 Jul 2025 13:16:50 GMT
# 25    Fri, 25 Jul 2025 14:03:55 GMT
# 26  Tue, 05 Aug 2025 23:04:22 +0000
# 27  Tue, 05 Aug 2025 22:37:08 +0000
# 28  Tue, 05 Aug 2025 20:10:19 +0000
# 29  Tue, 05 Aug 2025 20:09:10 +0000
# 30  Tue, 05 Aug 2025 18:43:50 +0000
#
#                                                  link
# 0   https://www.bbc.com/news/articles/cpqv2qjg5vvo...
# 1   https://www.bbc.com/news/articles/cewyk4ezeedo...
# 2   https://www.bbc.com/news/articles/crkznje8nz8o...
# 3   https://www.bbc.com/news/articles/crr2dwn7q40o...
# 4   https://www.bbc.com/news/articles/cx2x5eyl676o...
# 5   https://www.bbc.com/news/articles/c8x5jnl5eygo...
# 6   https://www.bbc.com/news/articles/c5yl7n42325o...
# 7   https://www.bbc.com/news/articles/cvgn6979n59o...
# 8   https://www.bbc.com/news/articles/cly6rl6158no...
# 9   https://www.bbc.com/news/articles/c74z4gy5g31o...
# 10  https://www.bbc.com/news/articles/cvgn2rwk2lyo...
# 11  https://www.bbc.com/news/articles/c4g2gw62jnpo...
# 12  https://www.bbc.com/news/articles/cm2ljemmnyko...
# 13  https://www.bbc.com/news/videos/cj0m5285d43o?a...
# 14  https://www.bbc.com/news/articles/cp863mln0pmo...
# 15  https://www.bbc.com/news/articles/c9dgv7v1d06o...
# 16  https://www.bbc.com/news/videos/cjelp738zd7o?a...
# 17  https://www.bbc.com/news/videos/cgerj7qnprno?a...
# 18  https://www.bbc.com/news/videos/cjey0v4xjz9o?a...
# 19  https://www.bbc.com/news/videos/c9d0lj9q9j6o?a...
# 20  https://www.bbc.com/news/videos/cgerj7qnprno?a...
# 21  https://www.bbc.com/news/videos/clyj4gnzxgno?a...
# 22  https://www.bbc.com/news/videos/c4gdg13rrx4o?a...
# 23  https://www.bbc.com/news/videos/cy8k8045nx9o?a...
# 24  https://www.bbc.com/news/videos/cgq7qpqz27qo?a...
# 25  https://www.bbc.com/news/videos/c4g8gy52dwgo?a...
# 26  https://www.aljazeera.com/news/2025/8/5/trump-...
# 27  https://www.aljazeera.com/video/the-take-2/202...
# 28  https://www.aljazeera.com/news/2025/8/5/israel...
# 29  https://www.aljazeera.com/video/newsfeed/2025/...
# 30  https://www.aljazeera.com/video/inside-story/2...
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e53dd39ebfee888fbd85a75a9c9d48ad {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e53dd39ebfee888fbd85a75a9c9d48ad&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e53dd39ebfee888fbd85a75a9c9d48ad = L.map(
#                 &quot;map_e53dd39ebfee888fbd85a75a9c9d48ad&quot;,
#                 {
#                     center: [33.5, 40.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8d5d6bf8441077a4f17539dc25750eaf = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_8d5d6bf8441077a4f17539dc25750eaf.addTo(map_e53dd39ebfee888fbd85a75a9c9d48ad);
#
#
#             var circle_marker_2f7a6a85410f3bca53f4b98389dec649 = L.circleMarker(
#                 [31.5, 34.47],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_e53dd39ebfee888fbd85a75a9c9d48ad);
#
#
#         var popup_7ae93c86e401a4c83f5cd11b29c8e803 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1c94fa5e573f04095fba0803f29d06e4 = $(`&lt;div id=&quot;html_1c94fa5e573f04095fba0803f29d06e4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Gaza — Risk Score: 100 (31 articles)&lt;/div&gt;`)[0];
#                 popup_7ae93c86e401a4c83f5cd11b29c8e803.setContent(html_1c94fa5e573f04095fba0803f29d06e4);
#
#
#
#         circle_marker_2f7a6a85410f3bca53f4b98389dec649.bindPopup(popup_7ae93c86e401a4c83f5cd11b29c8e803)
#         ;
#
#
#
#
#             var circle_marker_e7e95fb0609d6213a93f30dc7447be90 = L.circleMarker(
#                 [33.89, 35.5],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_e53dd39ebfee888fbd85a75a9c9d48ad);
#
#
#         var popup_af2ac30cfc804fc93aa0c03f5f9880d1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_40d38473df3b12357f6c38ef34f2f183 = $(`&lt;div id=&quot;html_40d38473df3b12357f6c38ef34f2f183&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Beirut — Risk Score: 0 (0 articles)&lt;/div&gt;`)[0];
#                 popup_af2ac30cfc804fc93aa0c03f5f9880d1.setContent(html_40d38473df3b12357f6c38ef34f2f183);
#
#
#
#         circle_marker_e7e95fb0609d6213a93f30dc7447be90.bindPopup(popup_af2ac30cfc804fc93aa0c03f5f9880d1)
#         ;
#
#
#
#
#             var circle_marker_d3b1cd753add6cd396e478349a592001 = L.circleMarker(
#                 [33.31, 44.36],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_e53dd39ebfee888fbd85a75a9c9d48ad);
#
#
#         var popup_9175e865ed55b021c0cc785fe240cc90 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c40a18208bb4e5e68f75b34e1b8c46ae = $(`&lt;div id=&quot;html_c40a18208bb4e5e68f75b34e1b8c46ae&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Baghdad — Risk Score: 0 (0 articles)&lt;/div&gt;`)[0];
#                 popup_9175e865ed55b021c0cc785fe240cc90.setContent(html_c40a18208bb4e5e68f75b34e1b8c46ae);
#
#
#
#         circle_marker_d3b1cd753add6cd396e478349a592001.bindPopup(popup_9175e865ed55b021c0cc785fe240cc90)
#         ;
#
#
#
#
#             var circle_marker_0970a47a85c

# %%
risk_data = fetch_risk_data(city_coords.keys(), rss_feeds)
print("Risk data:", risk_data)
# Out:
# Risk data: {'Beirut': 0, 'Baghdad': 0, 'Damascus': 0, 'Jerusalem': 2}

# %%
m = folium.Map(location=[33.5, 36.5], zoom_start=6)

for city, coords in city_coords.items():
    count = risk_data.get(city, 0)
    risk = get_risk_level(count)
    color = {"High": "red", "Medium": "orange", "Low": "green", "No data": "gray"}.get(risk, "gray")
    folium.Marker(
        location=coords,
        popup=f"<b>{city}</b><br>Articles: {count}<br>Risk: {risk}",
        tooltip=f"{city}: {risk}",
        icon=folium.Icon(color=color)
    ).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_50a0918ec73753de1ac3fc861c968609 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_50a0918ec73753de1ac3fc861c968609&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_50a0918ec73753de1ac3fc861c968609 = L.map(
#                 &quot;map_50a0918ec73753de1ac3fc861c968609&quot;,
#                 {
#                     center: [33.5, 36.5],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_60a4df1387af4f43a660e6e6e93532da = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_60a4df1387af4f43a660e6e6e93532da.addTo(map_50a0918ec73753de1ac3fc861c968609);
#
#
#             var marker_3bbfbf0ac528fffc1cbb47ca1de62248 = L.marker(
#                 [33.8938, 35.5018],
#                 {
# }
#             ).addTo(map_50a0918ec73753de1ac3fc861c968609);
#
#
#             var icon_4977144dd7786ac758d97d8de1a4b0e0 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_82ddd07db98b261dfc8e54022dd3987b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_dc8d3b6369244a9bd02000ca53e3a997 = $(`&lt;div id=&quot;html_dc8d3b6369244a9bd02000ca53e3a997&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Beirut&lt;/b&gt;&lt;br&gt;Articles: 0&lt;br&gt;Risk: Low&lt;/div&gt;`)[0];
#                 popup_82ddd07db98b261dfc8e54022dd3987b.setContent(html_dc8d3b6369244a9bd02000ca53e3a997);
#
#
#
#         marker_3bbfbf0ac528fffc1cbb47ca1de62248.bindPopup(popup_82ddd07db98b261dfc8e54022dd3987b)
#         ;
#
#
#
#
#             marker_3bbfbf0ac528fffc1cbb47ca1de62248.bindTooltip(
#                 `&lt;div&gt;
#                      Beirut: Low
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_3bbfbf0ac528fffc1cbb47ca1de62248.setIcon(icon_4977144dd7786ac758d97d8de1a4b0e0);
#
#
#             var marker_713d5e81aae79fccc90d4c9f2cb456d3 = L.marker(
#                 [33.3152, 44.3661],
#                 {
# }
#             ).addTo(map_50a0918ec73753de1ac3fc861c968609);
#
#
#             var icon_67ccd94d2907489832f6a56682bab8d5 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_606aa2a204307b81f91157953f9f12ef = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_286c874b0d9c3ae440e4d91047a63d22 = $(`&lt;div id=&quot;html_286c874b0d9c3ae440e4d91047a63d22&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Baghdad&lt;/b&gt;&lt;br&gt;Articles: 0&lt;br&gt;Risk: Low&lt;/div&gt;`)[0];
#                 popup_606aa2a204307b81f91157953f9f12ef.setContent(html_286c874b0d9c3ae440e4d91047a63d22);
#
#
#
#         marker_713d5e81aae79fccc90d4c9f2cb456d3.bindPopup(popup_606aa2a204307b81f91157953f9f12ef)
#         ;
#
#
#
#
#             marker_713d5e81aae79fccc90d4c9f2cb456d3.bindTooltip(
#                 `&lt;div&gt;
#                      Baghdad: Low
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_713d5e81aae79fccc90d4c9f2cb456d3.setIcon(icon_67ccd94d2907489832f6a56682bab8d5);
#
#
#             var marker_4808c31c35d68f2074fff26bdf90ed09 = L.marker(
#                 [33.5138, 36.2765],
#                 {
# }
#             ).addTo(map_50a0918ec73753de1ac3fc861c968609);
#
#
#             var icon_c690b7166eac7cfb03b9f3f6276a582e = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_a9c05db104f980ddd99e37d878b9f44e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_29cc10d56a4eb53b8ceb40b520a16879 = $(`&lt;div id
